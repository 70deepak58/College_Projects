# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SHIVAM.csv')
df
# Out:
#     _source/layers/frame/frame.interface_id_tree/frame.interface_name  \
# 0                                              s1-eth1
# 1                                              s1-eth1
# 2                                              s1-eth1
# 3                                              s1-eth1
# 4                                              s1-eth1
# ..                                                 ...
# 226                                            s1-eth1
# 227                                            s1-eth1
# 228                                            s1-eth1
# 229                                            s1-eth1
# 230                                            s1-eth1
#
#      _source/layers/frame/frame.encap_type  \
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
# ...

# %%
y = df['_source/layers/ip/ip.host']
y
# Out:
# 0      10.0.0.2
# 1      10.0.0.1
# 2      10.0.0.4
# 3      10.0.0.2
# 4      10.0.0.1
#          ...
# 226    10.0.0.1
# 227    10.0.0.2
# 228    10.0.0.1
# 229    10.0.0.3
# 230    10.0.0.1
# Name: _source/layers/ip/ip.host, Length: 231, dtype: object

# %%
df.drop(labels=['_source/layers/ip/ip.src'],inplace=True,axis=1)

# %%
df['_source/layers/ip/ip.src']=y

# %%
df
# Out:
#      _source/layers/frame/frame.interface_id_tree/frame.interface_name  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 226                                                  0
# 227                                                  0
# 228                                                  0
# 229                                                  0
# 230                                                  0
#
#      _source/layers/frame/frame.encap_type  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
def model_insights(model):
    m = model.fit(x_train,y_train)
    ypred = m.predict(x_test)
    print('Confusion Matrix\n',confusion_matrix(y_test,ypred))
    print('Accuracy_Score',accuracy_score(y_test,ypred))  # test accuracy
    print('Classification Report\n',classification_report(y_test,ypred))

# %%
lb = LabelEncoder()
for i in df.columns:
    df[i]=lb.fit_transform(df[i])
    
df
# Out:
#      _source/layers/frame/frame.interface_id_tree/frame.interface_name  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 226                                                  0
# 227                                                  0
# 228                                                  0
# 229                                                  0
# 230                                                  0
#
#      _source/layers/frame/frame.encap_type  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
print(x)
print(y)
# Out:
#      _source/layers/frame/frame.interface_id_tree/frame.interface_name  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 226                                                  0
# 227                                                  0
# 228                                                  0
# 229                                                  0
# 230                                                  0
#
#      _source/layers/frame/frame.encap_type  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (173, 62)
# (58, 62)
# (173,)
# (58,)

# %%
### DT Classifier
m3 = DecisionTreeClassifier(criterion='gini',max_depth=6)
model_insights(m3)
# Out:
# Confusion Matrix
#  [[28  0  0  0]
#  [ 0  8  0  0]
#  [ 0  0 11  0]
#  [ 0  0  0 11]]
# Accuracy_Score 1.0
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        28
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00        11
#            3       1.00      1.00      1.00        11
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58
